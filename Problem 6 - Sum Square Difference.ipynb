# %%
def sumsq_dif()

    return ans
# Out:
#   File "<ipython-input-1-ca31f8ec2bc2>", line 1
#     def sumsq_dif()
#                    ^
# SyntaxError: invalid syntax

# %%
sumnum = 0
sumsq = 0
i = 1
while i <= 100:
    sumnum += i
    sumsq += i**2
    print(sumsq, sumnum**2)
    i +=1

dif = (sumnum**2) - sumsq
dif
# Out:
# 1 1
# 5 9
# 14 36
# 30 100
# 55 225
# 91 441
# 140 784
# 204 1296
# 285 2025
# 385 3025
# 506 4356
# 650 6084
# 819 8281
# 1015 11025
# 1240 14400
# 1496 18496
# 1785 23409
# 2109 29241
# 2470 36100
# 2870 44100
# 3311 53361
# 3795 64009
# 4324 76176
# 4900 90000
# 5525 105625
# 6201 123201
# 6930 142884
# 7714 164836
# 8555 189225
# 9455 216225
# 10416 246016
# 11440 278784
# 12529 314721
# 13685 354025
# 14910 396900
# 16206 443556
# 17575 494209
# 19019 549081
# 20540 608400
# 22140 672400
# 23821 741321
# 25585 815409
# 27434 894916
# 29370 980100
# 31395 1071225
# 33511 1168561
# 35720 1272384
# 38024 1382976
# 40425 1500625
# 42925 1625625
# 45526 1758276
# 48230 1898884
# 51039 2047761
# 53955 2205225
# 56980 2371600
# 60116 2547216
# 63365 2732409
# 66729 2927521
# 70210 3132900
# 73810 3348900
# 77531 3575881
# 81375 3814209
# 85344 4064256
# 89440 4326400
# 93665 4601025
# 98021 4888521
# 102510 5189284
# 107134 5503716
# 111895 5832225
# 116795 6175225
# 121836 6533136
# ...
